# %% [markdown]
# ## functions
# - *first-class* objects - can be assigned to variables and passed to other functions just like any other arguments
# - anonymous functions are called *lambda functions*
# - default arguments can be given to a function

# %%
def optional_arg(name="default_name"):
    print(name)

optional_arg() # prints default_name
optional_arg("ravi") # prints ravi
